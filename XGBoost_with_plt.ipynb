# %%
import os.path
import numpy as np
import pickle
import xgboost as xgb
from bayes_opt import BayesianOptimization
from sklearn import metrics
import pandas as pd


def mean_absolute_percentage_error(y_true, y_pred): 

    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

def mean_absolute_range_percentage_error(y_true, y_pred): 
    error = np.abs((y_val- y_pred))-10000
    error[error < 0] = 0
    return np.mean(error/y_true)*100

path = os.getcwd()

with open(path + '/data/OHE.pkl', 'rb') as file:
    OHE_train,OHE_val,OHE_test,feature_names_OHE = pickle.load(file)
with open(path + '/data/TFIDF.pkl', 'rb') as file:
    TFIDF_train,TFIDF_val,TFIDF_test,feature_names_TFIDF = pickle.load(file)
with open(path + '/data/BOG.pkl', 'rb') as file:
    BOG_train,BOG_val,BOG_test,feature_names_BOG = pickle.load(file)
with open(path + '/data/TECH.pkl', 'rb') as file:    
    TECH_train,TECH_val,TECH_test,feature_names_TECH = pickle.load(file)
with open(path + '/data/yTrainValTest.pkl', 'rb') as file:
        y_train,y_val,y_test= pickle.load(file) 



X_train = pd.DataFrame(np.hstack((OHE_train,TFIDF_train)), columns = list(feature_names_OHE)+list(feature_names_TFIDF))
X_val = pd.DataFrame(np.hstack((OHE_val,TFIDF_val)), columns =list(feature_names_OHE)+list(feature_names_TFIDF))
X_test = pd.DataFrame(np.hstack((OHE_test,TFIDF_test)), columns = list(feature_names_OHE)+list(feature_names_TFIDF))


#remove 'company' variables
cols = [c for c in X_train.columns if 'company_' not in c]

X_train = X_train[cols]
X_val = X_val[cols]
X_test = X_test[cols]
feature_names = cols


params = {
    # Learning Task Parameters
    'objective': 'reg:squarederror',
    'eval_metric': 'rmse',  # Evaluation metrics for validation data
    # Parameters for Tree Booster
    'learning_rate': 0.05,  # Learning Rate: step size shrinkage used to prevent overfitting.
    # Paramters for XGB ScikitLearn API
    'n_jobs': -1,  # Number of parallel threads used to run xgboost
    'n_estimators': 1000,  # number of trees you want to build
    'verbosity': 1,  # degree of verbosity: 0 (silent) - 3 (debug)
    'max_depth': 4,
    'reg_lambda': 1,
    'colsample_bytree': 0.5,
    'subsample': 0.9
}
fit_params = {
    'eval_metric': 'rmse',
    'early_stopping_rounds': 3,
    'eval_set': [(X_val, y_val)],
}
xgb_reg = xgb.XGBRegressor(**params)

xgb_reg.fit(X_train, y_train, **fit_params)

df_DM = xgb.DMatrix(data=X_train, label=y_train)

def xgb_evaluate(max_depth, reg_lambda, colsample_bytree, subsample, min_child_weight):
    params1 = {
        'colsample_bytree': colsample_bytree,
        'max_depth': int(round(max_depth)),  # Maximum depth of a tree: high value
        # -> prone to overfitting
        'reg_lambda': reg_lambda,  # L2 regularization term on weights
        'subsample': subsample,
        'min_child_weight': min_child_weight
    }
    cv_result = xgb.cv(dtrain=df_DM,
                       params=params1,
                       early_stopping_rounds=3,
                       num_boost_round=1000,
                       metrics='rmse')
    return -cv_result['test-rmse-mean'].iloc[-1]


optimizer = BayesianOptimization(xgb_evaluate, {'max_depth': (3, 10),
                                                'reg_lambda': (0, 5),
                                                'colsample_bytree': (0.3, 1),
                                                'subsample': (0.5, 1),
                                                'min_child_weight': (1, 8)})

optimizer.maximize(init_points=10, n_iter=10)

params_1 = optimizer.max['params']
params_1['max_depth'] = int(round(params_1['max_depth']))
params.update(params_1)

xgb_reg = xgb.XGBRegressor(**params)
xgb_reg.fit(X_train, y_train, **fit_params)

y_pred = xgb_reg.predict(X_val)

print('Mean Absolute Error: {0:.0f}'.format( metrics.mean_absolute_error(y_val, y_pred)))
print('Mean Absolute Percentage Error: {0:.1f}'.format(mean_absolute_percentage_error(y_val, y_pred)))
print('Mean Absolute Range Percentage Error: {0:.1f}'.format(mean_absolute_range_percentage_error(y_val, y_pred)))

print('Mean Squared Error: {0:.0f}'.format(metrics.mean_squared_error(y_val, y_pred)))
print('Root Mean Squared Error:{0:.0f}'.format(np.sqrt(metrics.mean_squared_error(y_val, y_pred))))
print('R2 Score:{0:.2f}'.format(np.sqrt(metrics.r2_score(y_val, y_pred))))
# Out:
# C:\Users\lundr\AppData\Local\Continuum\anaconda3\envs\dsj\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# C:\Users\lundr\AppData\Local\Continuum\anaconda3\envs\dsj\lib\site-packages\xgboost\core.py:588: FutureWarning: Series.base is deprecated and will be removed in a future version
#   data.base is not None and isinstance(data, np.ndarray) \
# [0]	validation_0-rmse:70859.5
# Will train until validation_0-rmse hasn't improved in 3 rounds.
# [1]	validation_0-rmse:68059.6
# [2]	validation_0-rmse:65173.9
# [3]	validation_0-rmse:62666.1
# [4]	validation_0-rmse:60046.5
# [5]	validation_0-rmse:57716.6
# [6]	validation_0-rmse:55380.2
# [7]	validation_0-rmse:53199.2
# [8]	validation_0-rmse:51282.3
# [9]	validation_0-rmse:49440
# [10]	validation_0-rmse:47818.7
# [11]	validation_0-rmse:46092.3
# [12]	validation_0-rmse:44559.9
# [13]	validation_0-rmse:43173.5
# [14]	validation_0-rmse:41713.7
# [15]	validation_0-rmse:40398.9
# [16]	validation_0-rmse:39132.9
# [17]	validation_0-rmse:38053.9
# [18]	validation_0-rmse:36978.9
# [19]	validation_0-rmse:35880
# [20]	validation_0-rmse:34950
# [21]	validation_0-rmse:33994.5
# [22]	validation_0-rmse:33172
# [23]	validation_0-rmse:32415.6
# [24]	validation_0-rmse:31620.7
# [25]	validation_0-rmse:30895.2
# [26]	validation_0-rmse:30354.4
# [27]	validation_0-rmse:29770.9
# [28]	validation_0-rmse:29207.7
# [29]	validation_0-rmse:28738.4
# [30]	validation_0-rmse:28252.9
# [31]	validation_0-rmse:27833.3
# [32]	validation_0-rmse:27392.2
# [33]	validation_0-rmse:27104.1
# [34]	validation_0-rmse:26735.6
# [35]	validation_0-rmse:26429.5
# [36]	validation_0-rmse:26187.2
# [37]	validation_0-rmse:25905.1
# [38]	validation_0-rmse:25600.3
# [39]	validation_0-rmse:25343.5
# [40]	validation_0-rmse:25090.6
# [41]	validation_0-rmse:24859.5
# [42]	validation_0-rmse:24657.7
# [43]	validation_0-rmse:24464.9
# [44]	validation_0-rmse:24303.7
# [45]	validation_0-rmse:24139.3
# [46]	validation_0-rmse:24019
# [47]	validation_0-rmse:23900.9
# [48]	validation_0-rmse:23767.6
# [49]	validation_0-rmse:23667.3
# [50]	validation_0-rmse:23571.9
# [51]	validation_0-rmse:23475.1
# [52]	validation_0-rmse:23376.3
# [53]	validation_0-rmse:23314.8
# [54]	validation_0-rmse:23237.4
# [55]	validation_0-rmse:23159.1
# [56]	validation_0-rmse:23105.4
# [57]	validation_0-rmse:23026.1
# [58]	validation_0-rmse:22976
# [59]	validation_0-rmse:22911.8
# [60]	validation_0-rmse:22849.8
# [61]	validation_0-rmse:22801.6
# [62]	validation_0-rmse:22736.8
# [63]	validation_0-rmse:22700.2
# [64]	validation_0-rmse:22646.2
# [65]	validation_0-rmse:22603.7
# [66]	validation_0-rmse:22571
# [67]	validation_0-rmse:22527.6
# [68]	validation_0-rmse:22499.2
# [69]	validation_0-rmse:22457.2
# [70]	validation_0-rmse:22409
# [71]	validation_0-rmse:22367.4
# [72]	validation_0-rmse:22355.1
# [73]	validation_0-rmse:22294.9
# [74]	validation_0-rmse:22272.9
# [75]	validation_0-rmse:22243.6
# [76]	validation_0-rmse:22218.9
# [77]	validation_0-rmse:22195.5
# [78]	validation_0-rmse:22174.6
# [79]	validation_0-rmse:22158.1
# [80]	validation_0-rmse:22134.4
# [81]	validation_0-rmse:22108.5
# [82]	validation_0-rmse:22083.3
# [83]	validation_0-rmse:22053.1
# [84]	validation_0-rmse:22029.9
# [85]	validation_0-rmse:22017.2
# [86]	validation_0-rmse:21977.9
# [87]	validation_0-rmse:21958.4
# [88]	validation_0-rmse:21922.1
# [89]	validation_0-rmse:21911
# [90]	validation_0-rmse:21895.7
# [91]	validation_0-rmse:21880.9
# [92]	validation_0-rmse:21858.8
# [93]	validation_0-rmse:21833.2
# [94]	validation_0-rmse:21812
# [95]	validation_0-rmse:21792.6
# [96]	validation_0-rmse:21777.6
# [97]	validation_0-rmse:21770.8
# [98]	validation_0-rmse:21764.5
# [99]	validation_0-rmse:21757.3
# [100]	validation_0-rmse:21744
# [101]	validation_0-rmse:21735.2
# [102]	validation_0-rmse:21714.6
# [103]	validation_0-rmse:21702
# [104]	validation_0-rmse:21677.6
# [105]	validation_0-rmse:21657.7
# [106]	validation_0-rmse:21652.1
# [107]	validation_0-rmse:21640.4
# [108]	validation_0-rmse:21616.4
# [109]	validation_0-rmse:21613.1
# [110]	validation_0-rmse:21596.6
# [111]	validation_0-rmse:21581.5
# [112]	validation_0-rmse:21574.8
# [113]	validation_0-rmse:21554.3
# [114]	validation_0-rmse:21542.7
# [115]	validation_0-rmse:21538.7
# [116]	validation_0-rmse:21518.2
# [117]	validation_0-rmse:21515.3
# [118]	validation_0-rmse:21498.4
# [119]	validation_0-rmse:21483.3
# [120]	validation_0-rmse:21481.4
# [121]	validation_0-rmse:21480.6
# [122]	validation_0-rmse:21468.6
# [123]	validation_0-rmse:21451.5
# [124]	validation_0-rmse:21433.1
# [125]	validation_0-rmse:21429.2
# [126]	validation_0-rmse:21419
# [127]	validation_0-rmse:21403.7
# [128]	validation_0-rmse:21402.1
# [129]	validation_0-rmse:21388
# [130]	validation_0-rmse:21384.4
# [131]	validation_0-rmse:21375
# [132]	validation_0-rmse:21364.6
# [133]	validation_0-rmse:21353.9
# [134]	validation_0-rmse:21344.8
# [135]	validation_0-rmse:21332.6
# [136]	validation_0-rmse:21323
# [137]	validation_0-rmse:21307.8
# [138]	validation_0-rmse:21304.3
# [139]	validation_0-rmse:21302.2
# [140]	validation_0-rmse:21291.9
# [141]	validation_0-rmse:21281.2
# [142]	validation_0-rmse:21281.7
# [143]	validation_0-rmse:21278.7
# [144]	validation_0-rmse:21266.7
# [145]	validation_0-rmse:21258.2
# [146]	validation_0-rmse:21246.4
# [147]	validation_0-rmse:21233.9
# [148]	validation_0-rmse:21234.5
# [149]	validation_0-rmse:21218.8
# [150]	validation_0-rmse:21206.7
# [151]	validation_0-rmse:21209.6
# [152]	validation_0-rmse:21203.3
# [153]	validation_0-rmse:21187.2
# [154]	validation_0-rmse:21177.8
# [155]	validation_0-rmse:21179.6
# [156]	validation_0-rmse:21183.9
# [157]	validation_0-rmse:21179.4
# Stopping. Best iteration:
# [154]	validation_0-rmse:21177.8
#
# |   iter    |  target   | colsam... | max_depth | min_ch... | reg_la... | subsample |
# -------------------------------------------------------------------------------------
# |  1        | -2.251e+0 |  0.3005   |  5.096    |  4.5      |  0.2533   |  0.866    |
# |  2        | -2.221e+0 |  0.8165   |  4.59     |  7.692    |  0.7553   |  0.8034   |
# |  3        | -2.253e+0 |  0.6152   |  5.096    |  4.407    |  2.26     |  0.5383   |
# |  4        | -2.259e+0 |  0.7827   |  4.699    |  3.893    |  2.602    |  0.8      |
# |  5        | -2.241e+0 |  0.7842   |  4.768    |  7.117    |  3.003    |  0.6953   |
# |  6        | -2.239e+0 |  0.5448   |  7.606    |  4.732    |  0.5469   |  0.6062   |
# |  7        | -2.251e+0 |  0.6987   |  3.627    |  1.217    |  4.367    |  0.5228   |
# |  8        | -2.23e+04 |  0.4518   |  5.677    |  6.936    |  4.388    |  0.9049   |
# |  9        | -2.248e+0 |  0.9612   |  4.517    |  4.73     |  3.209    |  0.6465   |
# |  10       | -2.27e+04 |  0.9561   |  6.078    |  2.923    |  4.7      |  0.8207   |
# |  11       | -2.241e+0 |  0.8168   |  4.593    |  7.697    |  0.7649   |  0.8032   |
# |  12       | -2.248e+0 |  0.3353   |  3.45     |  7.137    |  0.2848   |  0.6075   |
# |  13       | -2.189e+0 |  0.6634   |  8.279    |  6.602    |  3.65     |  0.9037   |
# |  14       | -2.247e+0 |  0.7144   |  9.274    |  5.702    |  2.206    |  0.7907   |
# |  15       | -2.222e+0 |  0.9759   |  8.335    |  2.112    |  3.354    |  0.8413   |
# |  16       | -2.242e+0 |  0.3904   |  5.822    |  5.398    |  2.006    |  0.8161   |
# |  17       | -2.24e+04 |  0.3887   |  6.758    |  1.773    |  4.173    |  0.8638   |
# |  18       | -2.257e+0 |  0.8682   |  9.779    |  5.947    |  2.077    |  0.7947   |
# |  19       | -2.207e+0 |  0.5282   |  3.769    |  1.188    |  2.654    |  0.7775   |
# |  20       | -2.278e+0 |  0.4804   |  9.35     |  6.266    |  4.409    |  0.7538   |
# =====================================================================================
# C:\Users\lundr\AppData\Local\Continuum\anaconda3\envs\dsj\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# C:\Users\lundr\AppData\Local\Continuum\anaconda3\envs\dsj\lib\site-packages\xgboost\core.py:588: FutureWarning: Series.base is deprecated and will be removed in a future version
#   data.base is not None and isinstance(data, np.ndarray) \
# [0]	validation_0-rmse:70914.8
# Will train until validation_0-rmse hasn't improved in 3 rounds.
# [1]	validation_0-rmse:68050.9
# [2]	validation_0-rmse:65191.4
# [3]	validation_0-rmse:62543.4
# [4]	validation_0-rmse:59987.6
# [5]	validation_0-rmse:57624.5
# [6]	validation_0-rmse:55290
# [7]	validation_0-rmse:53134.9
# [8]	validation_0-rmse:51053.9
# [9]	validation_0-rmse:49094.5
# [10]	validation_0-rmse:47376.1
# [11]	validation_0-rmse:45650.6
# [12]	validation_0-rmse:44053.1
# [13]	validation_0-rmse:42635.9
# [14]	validation_0-rmse:41201.4
# [15]	validation_0-rmse:39810.5
# [16]	validation_0-rmse:38561.8
# [17]	validation_0-rmse:37379
# [18]	validation_0-rmse:36278.3
# [19]	validation_0-rmse:35247.8
# [20]	validation_0-rmse:34268.8
# [21]	validation_0-rmse:33320.7
# [22]	validation_0-rmse:32434.7
# [23]	validation_0-rmse:31585
# [24]	validation_0-rmse:30829.7
# [25]	validation_0-rmse:30145
# [26]	validation_0-rmse:29522
# [27]	validation_0-rmse:28961.5
# [28]	validation_0-rmse:28418.3
# [29]	validation_0-rmse:27875.8
# [30]	validation_0-rmse:27393.7
# [31]	validation_0-rmse:26970.8
# [32]	validation_0-rmse:26575.7
# [33]	validation_0-rmse:26221.7
# [34]	validation_0-rmse:25859.1
# [35]	validation_0-rmse:25512.2
# [36]	validation_0-rmse:25218.1
# [37]	validation_0-rmse:24913.1
# [38]	validation_0-rmse:24636.3
# [39]	validation_0-rmse:24386.8
# [40]	validation_0-rmse:24153.6
# [41]	validation_0-rmse:23926
# [42]	validation_0-rmse:23730.7
# [43]	validation_0-rmse:23557.4
# [44]	validation_0-rmse:23380.1
# [45]	validation_0-rmse:23205.2
# [46]	validation_0-rmse:23066.8
# [47]	validation_0-rmse:22922.4
# [48]	validation_0-rmse:22808.7
# [49]	validation_0-rmse:22678.4
# [50]	validation_0-rmse:22571.7
# [51]	validation_0-rmse:22491.8
# [52]	validation_0-rmse:22410.3
# [53]	validation_0-rmse:22329.1
# [54]	validation_0-rmse:22224.5
# [55]	validation_0-rmse:22149
# [56]	validation_0-rmse:22070.4
# [57]	validation_0-rmse:22007.2
# [58]	validation_0-rmse:21951.9
# [59]	validation_0-rmse:21895
# [60]	validation_0-rmse:21841
# [61]	validation_0-rmse:21805.5
# [62]	validation_0-rmse:21744.8
# [63]	validation_0-rmse:21692.2
# [64]	validation_0-rmse:21642.2
# [65]	validation_0-rmse:21591.9
# [66]	validation_0-rmse:21555.1
# [67]	validation_0-rmse:21520.2
# [68]	validation_0-rmse:21481.1
# [69]	validation_0-rmse:21448.3
# [70]	validation_0-rmse:21416.6
# [71]	validation_0-rmse:21384.2
# [72]	validation_0-rmse:21350.1
# [73]	validation_0-rmse:21320.8
# [74]	validation_0-rmse:21292.2
# [75]	validation_0-rmse:21271.8
# [76]	validation_0-rmse:21245.5
# [77]	validation_0-rmse:21225.5
# [78]	validation_0-rmse:21196.7
# [79]	validation_0-rmse:21178.4
# [80]	validation_0-rmse:21162.6
# [81]	validation_0-rmse:21141.9
# [82]	validation_0-rmse:21123
# [83]	validation_0-rmse:21115.6
# [84]	validation_0-rmse:21104.8
# [85]	validation_0-rmse:21092.7
# [86]	validation_0-rmse:21075.1
# [87]	validation_0-rmse:21050.7
# [88]	validation_0-rmse:21039.1
# [89]	validation_0-rmse:21026.4
# [90]	validation_0-rmse:21006
# [91]	validation_0-rmse:20997.7
# [92]	validation_0-rmse:20999.6
# [93]	validation_0-rmse:20974.1
# [94]	validation_0-rmse:20955.1
# [95]	validation_0-rmse:20947.4
# [96]	validation_0-rmse:20933.5
# [97]	validation_0-rmse:20921.5
# [98]	validation_0-rmse:20910.9
# [99]	validation_0-rmse:20900.6
# [100]	validation_0-rmse:20899.1
# [101]	validation_0-rmse:20885.5
# [102]	validation_0-rmse:20865.2
# [103]	validation_0-rmse:20854.2
# [104]	validation_0-rmse:20826.5
# [105]	validation_0-rmse:20817.2
# [106]	validation_0-rmse:20815.3
# [107]	validation_0-rmse:20809.3
# [108]	validation_0-rmse:20808
# [109]	validation_0-rmse:20806.9
# [110]	validation_0-rmse:20799.9
# [111]	validation_0-rmse:20795.1
# [112]	validation_0-rmse:20789.5
# [113]	validation_0-rmse:20785.1
# [114]	validation_0-rmse:20791.4
# [115]	validation_0-rmse:20788.9
# [116]	validation_0-rmse:20780.9
# [117]	validation_0-rmse:20770
# [118]	validation_0-rmse:20764.3
# [119]	validation_0-rmse:20752.6
# [120]	validation_0-rmse:20738.7
# [121]	validation_0-rmse:20735.9
# [122]	validation_0-rmse:20735.9
# [123]	validation_0-rmse:20720.8
# [124]	validation_0-rmse:20710.5
# [125]	validation_0-rmse:20710.5
# [126]	validation_0-rmse:20711.7
# [127]	validation_0-rmse:20707.1
# [128]	validation_0-rmse:20706.8
# [129]	validation_0-rmse:20711.3
# [130]	validation_0-rmse:20708.9
# [131]	validation_0-rmse:20699.8
# [132]	validation_0-rmse:20697
# [133]	validation_0-rmse:20684.4
# [134]	validation_0-rmse:20678.9
# [135]	validation_0-rmse:20679.1
# [136]	validation_0-rmse:20673
# [137]	validation_0-rmse:20665.3
# [138]	validation_0-rmse:20661.8
# [139]	validation_0-rmse:20660.6
# [140]	validation_0-rmse:20656.3
# [141]	validation_0-rmse:20653.1
# [142]	validation_0-rmse:20653.4
# [143]	validation_0-rmse:20649.7
# [144]	validation_0-rmse:20648.9
# [145]	validation_0-rmse:20641.8
# [146]	validation_0-rmse:20636.3
# [147]	validation_0-rmse:20636.1
# [148]	validation_0-rmse:20634.7
# [149]	validation_0-rmse:20624.3
# [150]	validation_0-rmse:20627.8
# [151]	validation_0-rmse:20620.3
# [152]	validation_0-rmse:20619.8
# [153]	validation_0-rmse:20618.7
# [154]	validation_0-rmse:20617.1
# [155]	validation_0-rmse:20621.5
# [156]	validation_0-rmse:20619.6
# [157]	validation_0-rmse:20614.7
# [158]	validation_0-rmse:20616.7
# [159]	validation_0-rmse:20616.3
# [160]	validation_0-rmse:20615.9
# Stopping. Best iteration:
# [157]	validation_0-rmse:20614.7
#
# Mean Absolute Error: 15194
# Mean Absolute Percentage Error: 29.4
# Mean Absolute Range Percentage Error: 12.8
# Mean Squared Error: 424965875
# Root Mean Squared Error:20615
# R2 Score:0.85

# %%
feature_importances = xgb_reg.feature_importances_

# %%
features = pd.concat([pd.DataFrame(feature_names),pd.DataFrame(feature_importances)],axis = 1)
features.columns = ['feature','importance']

# %%
import matplotlib.pyplot as plt
with plt.style.context('seaborn'):
    ax = plt.scatter(y_pred,y_val)
    plt.plot(y_pred, y_pred, color='black')
    plt.plot(y_pred, y_pred-15000, color='mediumspringgreen')
    plt.plot(y_pred, y_pred+15000, color='mediumspringgreen')
    plt.xlabel('y_pred')
    plt.ylabel('y_true')
