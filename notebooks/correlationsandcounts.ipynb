# %%
import psycopg2
from sqlalchemy import create_engine
import pandas as pd
from sklearn.preprocessing import MultiLabelBinarizer
import os
from datetime import date
import seaborn as sns

# %%
os.getcwd()
os.chdir('..')

# %%
# create engine to read from SQL
# PASSWORD = pd.read_pickle('C:/Users/lundr/DataScienceJobs/data/SQL_password.pkl').iloc[0,0]
# engine = create_engine('postgresql://postgres:'+PASSWORD+'@dsj-1.c9mo6xd9bf9d.us-west-2.rds.amazonaws.com:5432/')

# %%
df = pd.read_pickle('data/tech_encoded_data_data_scientist2019-11-22.pkl')
df = df.drop(columns=['ref_code','url','location','posted_date','extraction_date','index','id','language','jobtype',
                        'salary','salary_low','salary_high','salary_low_euros','salary_high_euros',
                        'currency','salary_type'])

# %%
corr = df.corr()

# %%
corrs = pd.DataFrame(corr['salary_average'].sort_values(ascending=False))
corrs = corrs.dropna()

# %%
corrs.head(50)
# Out:
#                          salary_average
# salary_average                 1.000000
# salary_average_euros           0.968113
#  etl                           0.196980
#  apache                        0.196980
#  agile                         0.117192
#  scala                         0.094696
#  prototype                     0.091608
#  data warehousing              0.091608
#  power bi                      0.070546
#                                0.069915
#  nosql                         0.064039
#  slick                         0.062772
#  tableau                       0.054608
#  business intelligence         0.050472
#  mysql                         0.047223
#  bash                          0.047223
#  travis ci                     0.047223
#  hbase                         0.047223
#  ruby                          0.047223
#  bigquery                      0.047223
#  cassandra                     0.047223
#  hdfs                          0.047223
# ...

# %%
counts = pd.DataFrame(df.sum(axis = 0, skipna = True))
counts=counts.drop(index=['T','iR'])
counts.columns = ['count']

# %%
counts
# Out:
#                                                    count
#  cross-platform mobile (mostly javascript)             0
#  activemq                                              0
#  slf4j                                                 0
#  xampp                                                 0
#  spark                                                69
# ...                                                  ...
#  clr                                                   0
# level_0                                           141514
# salary_average                               1.20257e+07
# salary_average_euros                         1.10226e+07
# selection                                            141
#
# [1437 rows x 1 columns]

# %%
counts.sort_values(by = 'count', ascending = False).head(50)
# Out:
#                                      count
# salary_average                 1.20257e+07
# salary_average_euros           1.10226e+07
# level_0                             141514
#                                        804
#  machine learning                      361
#  python                                303
#  sql                                   208
#  r                                     177
# selection                              141
#  deep learning                          85
#  spark                                  69
#  big data                               66
#  amazon web services                    66
#  nlp                                    60
#  hadoop                                 59
#  tableau                                46
#  natural language processing            41
#  database                               38
#  java                                   33
#  nosql                                  26
#  access                                 25
# ...
