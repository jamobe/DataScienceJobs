# %%
import pandas as pd
import numpy as np
from datetime import datetime

# %%
import os.path
path = os.getcwd()
parent_folder, current_folder = os.path.split(path)
parent_folder
# Out:
# '/Users/jamoth/DSR/DataScienceJobs'

# %%
df1 = pd.read_csv(parent_folder+'/data/indeed_de_2019_10_24_15_28.csv', sep='\t', index_col=0)
df2 = pd.read_csv(parent_folder+'/data/indeed_de_2019_10_24_16_10.csv', sep='\t', index_col=0)
df3 = pd.read_csv(parent_folder+'/data/indeed_de_2019_10_24_16_23.csv', sep='\t', index_col=0)
df4 = pd.read_csv(parent_folder+'/data/indeed_de_2019_10_25_14_43.csv', sep='\t', index_col=0)
df5 = pd.read_csv(parent_folder+'/data/indeed_de_2019_10_25_19_46.csv', sep='\t', index_col=0)
df6 = pd.read_csv(parent_folder+'/data/indeed_de_2019_11_04_21_54.csv', sep='\t', index_col=0)

# %%
print(df1.shape)
print(df2.shape)
print(df3.shape)
print(df4.shape)
print(df5.shape)
print(df6.shape)
# Out:
# (4216, 7)
# (2831, 7)
# (885, 7)
# (4123, 8)
# (3453, 8)
# (3428, 8)

# %%
df1['url'] = 'Not available'
df2['url'] = 'Not available'
df3['url'] = 'Not available'

# %%
df1['extraction_date'] = datetime(2019, 10, 24)
df2['extraction_date'] = datetime(2019, 10, 24)
df3['extraction_date'] = datetime(2019, 10, 24)
df4['extraction_date'] = datetime(2019, 10, 25)
df5['extraction_date'] = datetime(2019, 10, 25)
df6['extraction_date'] = datetime(2019, 11, 4)

# %%
df = df1.append(df2, ignore_index=True)
df = df.append(df3, ignore_index=True)
df = df.append(df4, ignore_index=True)
df = df.append(df5, ignore_index=True)
df = df.append(df6, ignore_index=True)

# %%
df.rename(columns={"title": "job_title"})
df.company = df.company.str.strip()
df.description = df.description.str.strip()

# %%
df.salary = df.salary.str.strip()
df['salary_low'] = df['salary'].str.split('-', n = 1, expand = True)[0]
df['salary_high'] = df['salary'].str.split('-', n = 1, expand = True)[1]

# %%
df['job_type'] = 'Not available'
df['industry'] = 'Not available'
df['education'] = 'Not available'
df['career'] = 'Not available'

# %%
df.to_csv(parent_folder + '/data/indeed_de_all.csv', index=True, sep='\t')

# %%
# Out:
#                                            description  \
# 0    Data Architect (Python SQL Azure TOGAF). Would...
# 1    We are a specialist economics research busines...
# 2    Data Entry We are recruiting for Data Entry in...
# 3    Data Architect  - Stratford, LondonAre you an ...
# 4    Administrator / Data Entry (Cluster Support)Lo...
# ..                                                 ...
# 800  Data ScientistAs one of Vodafone key strategic...
# 801  Quantitative Researcher - Data Scientist - Mac...
# 802  Data Analyst - Data Migration AnalystData Migr...
# 803  Data Engineer / Developer (SQL T-SQL NoSQL ETL...
# 804  Data EngineerAs one of Vodafone's key strategi...
#
#                                                 salary  \
# 0           £90,000.00 - £120,000.00  per yearbenefits
# 1    £112.00 - £135.00 /per daycould be part time o...
# 2                             £8.21 - £10.80  per hour
# 3            £65,000.00 - £75,000.00  per yearbenefits
# 4                    £21,000.00 - £25,000.00  per year
# ..                                                 ...
# 800                                                 []
# 801    £100,000.00 - £130,000.00  per year   Benefits:
# 802  £35,000.00 - £40,000.00  per yearBenefits + fl...
# 803  £70,000.00 - £85,000.00  per yearbonus + benefits
# 804                                                 []
#
#                             location                                jobtype  \
# 0                     London, London                   Full Time, Permanent
# 1              London, London W1U5HT  Part Time, Temporary/Contract/Project
# 2         Staffordshire, MID WS154RX  Full Time, Temporary/Contract/Project
# 3                  Stratford, London                   Full Time, Permanent
# 4    Middlesbrough, Yorkshire TS15JH                   Full Time, Permanent
# ..                               ...                                    ...
# 800           London, London rg142fn  Full Time, Temporary/Contract/Project
# 801                   London, London                   Full Time, Permanent
# 802    Southampton, Southern SO143JA                   Full Time, Permanent
# 803                   London, London                   Full Time, Permanent
# 804             London, London w26by  Full Time, Temporary/Contract/Project
#
#        duration                                           industry  \
# 0         Today            Computer Software; Computer/IT Services
# 1         Today                          Business Services - Other
# 2         Today  Travel, Transportation and Tourism ; Transport...
# 3         Today                               Computer/IT Services
# 4         Today                                                All
# ..          ...                                                ...
# 800  5 Days ago                        Telecommunications Services
# 801  5 Days ago                               Computer/IT Services
# 802  5 Days ago  Computer Hardware; Computer Software; Computer...
# 803  5 Days ago            Computer Software; Computer/IT Services
# 804  5 Days ago                        Telecommunications Services
#
#              education                     career  \
# 0          Unspecified                        NaN
# 1                  NaN                        NaN
# 2          Unspecified                        NaN
# 3          Unspecified                        NaN
# 4          Unspecified                        NaN
# ..                 ...                        ...
# 800        Unspecified                        NaN
# 801                NaN                        NaN
# 802  Bachelor's Degree  Experienced (Non-Manager)
# 803        Unspecified                        NaN
# 804        Unspecified                        NaN
#
#                             ref_code  \
# 0    bb/14380/a/ks/111019_1570791355
# 1                                NaN
# 2               chp_dearg_1570788272
# 3                js2566da_1571385205
# 4                   reference: 19217
# ..                               ...
# 800              50204581_1571233505
# 801                          mo56463
# 802               pg-da-1_1572458416
# 803  bb/14430/a/ks/231019_1571841037
# 804              50204582_1571238622
#
#                                                    url extraction_date  \
# 0    https://job-openings.monster.co.uk/data-archit...      2019-10-25
# 1    https://job-openings.monster.co.uk/operations-...      2019-10-25
# 2    https://job-openings.monster.co.uk/data-entry-...      2019-10-25
# 3    https://job-openings.monster.co.uk/data-archit...      2019-10-25
# 4    https://job-openings.monster.co.uk/administrat...      2019-10-25
# ..                                                 ...             ...
# 800  https://job-openings.monster.co.uk/data-scient...      2019-10-25
# 801  https://job-openings.monster.co.uk/quantitativ...      2019-10-25
# 802  https://job-openings.monster.co.uk/data-analys...      2019-10-25
# 803  https://job-openings.monster.co.uk/data-engine...      2019-10-25
# 804  https://job-openings.monster.co.uk/data-engine...      2019-10-25
#
#                                       job_title  \
# 0              Data Architect Python SQL Azure
# 1                      Operations/data manager
# 2                                   Data Entry
# 3                               Data Architect
# 4                   Administrator / Data Entry
# ..                                          ...
# 800                             Data Scientist
# 801                    Quantitative Researcher
# 802                               Data Analyst
# 803  Data Engineer SQL Data Warehouse ETL .Net
# 804                              Data Engineer
#
#                                                company    salary_low  \
# 0                                        Client Server   £90,000.00
# 1                            Now-Casting Economics Ltd      £112.00
# 2                                      Extra Personnel        £8.21
# 3              East London - Randstad Technologies Ltd   £65,000.00
# 4                                Northern Gas Networks   £21,000.00
# ..                                                 ...           ...
# 800                          Lorien Resourcing Limited            []
# 801                    Data Scientist - OHO Group Ltd.  £100,000.00
# 802   Data Migration, SQL, SSIS, Excel - £40k - Spe...   £35,000.00
# 803                                      Client Server   £70,000.00
# 804                          Lorien Resourcing Limited            []
#
#                                            salary_high
# 0                        £120,000.00  per yearbenefits
# 1     £135.00 /per daycould be part time or full ti...
# 2                                     £10.80  per hour
# 3                         £75,000.00  per yearbenefits
# 4                                 £25,000.00  per year
# ..                                                 ...
# 800                                                NaN
# 801                  £130,000.00  per year   Benefits:
# 802    £40,000.00  per yearBenefits + flexible working
# 803               £85,000.00  per yearbonus + benefits
# 804                                                NaN
#
# [3220 rows x 15 columns]
