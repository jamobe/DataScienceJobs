# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import os.path
path = os.getcwd()
parent_folder, current_folder = os.path.split(path)
parent_folder
# Out:
# '/Users/jamoth/DSR/DataScienceJobs'

# %%
df = pd.read_csv(parent_folder+'/data/monster_all.csv', sep='\t', index_col=0)

# %%
print(df.shape)
# Out:
# (1070, 15)

# %%
df.salary_low = df.salary_low.str.strip()
df.salary_low = df.salary_low.str.strip('£')
df.salary_low = df.salary_low.str.strip('€')
df.salary_low = df.salary_low.str.strip('$')
df.salary_low = df.salary_low.str.replace(',','')

# %%
df.salary_high = df.salary_high.str.split('per', n=1, expand=True)[0]
df.salary_high = df.salary_high.str.strip()
df.salary_high = df.salary_high.str.strip('£')
df.salary_high = df.salary_high.str.strip('€')
df.salary_high = df.salary_high.str.strip('$')
df.salary_high = df.salary_high.str.strip('/')
df.salary_high = df.salary_high.str.replace(',','')

# %%
df = df.dropna(subset=['salary_low', 'salary_high'])

# %%
df['salary_low'] = pd.to_numeric(df['salary_low'])
df['salary_high'] = pd.to_numeric(df['salary_high'])

# %%
# check for salary anomalies
df[df['salary_high']/df['salary_low']>3]
# Out:
#                                            description  \
# 404  Role:  Senior Data EngineerSalary: £45,000 - £...
# 569  Data Engineer Data Engineer needed for a growi...
# 834  Data Engineer Data Engineer needed for a growi...
#
#                                                 salary  \
# 404                 £45,000.00 - £650,000.00  per year
# 569  £35,000.00 - £600,000.00  per yearHoliday Fund...
# 834  £35,000.00 - £600,000.00  per yearHoliday Fund...
#
#                    location               jobtype    duration  \
# 404  City of London, London  Full Time, Permanent  2 Days ago
# 569    Manchester, NW M14BT  Full Time, Permanent       Today
# 834    Manchester, NW M14BT  Full Time, Permanent       Today
#
#                          industry     education                     career  \
# 404  Government and Public Sector   Unspecified                        NaN
# 569             Computer Software  Professional  Experienced (Non-Manager)
# 834             Computer Software  Professional  Experienced (Non-Manager)
#
#                  ref_code                                                url  \
# 404  bbbh20133_1571148379  https://job-openings.monster.co.uk/senior-data...
# 569  bbbh28217_1572870049  https://job-openings.monster.co.uk/data-engine...
# 834  bbbh28217_1572870049  https://job-openings.monster.co.uk/data-engine...
#
#     extraction_date              job_title                company  salary_low  \
# 404      2019-10-25  Senior Data Engineer    Talent International     45000.0
# 569      2019-10-25         Data Engineer     Cathcart Associates     35000.0
# 834      2019-11-05         Data Engineer     Cathcart Associates     35000.0
#
#      salary_high
# 404     650000.0
# 569     600000.0
# 834     600000.0

# %%
#correct the mistake
df.loc[df['salary_high']==max(df['salary_high']),'salary_high']=df['salary_low']*2

# %%
df['salary_average'] = (df['salary_low']+df['salary_high'])/2

# %%
df.dtypes
# Out:
# description         object
# salary              object
# location            object
# jobtype             object
# duration            object
# industry            object
# education           object
# career              object
# ref_code            object
# url                 object
# extraction_date     object
# job_title           object
# company             object
# salary_low         float64
# salary_high        float64
# salary_average     float64
# dtype: object

# %%
plt.hist(df['salary_average'])
# Out:
# (array([297., 274., 141.,  22.,   6.,   0.,   0.,   0.,   0.,   2.]),
#  array([1.5000000e+00, 3.1751350e+04, 6.3501200e+04, 9.5251050e+04,
#         1.2700090e+05, 1.5875075e+05, 1.9050060e+05, 2.2225045e+05,
#         2.5400030e+05, 2.8575015e+05, 3.1750000e+05]),
#  <a list of 10 Patch objects>)

# %%
df.location = df.location.str.split(',', n=1, expand=True)[0]

# %%
df.groupby(by='location').agg({'salary_average' : ['count','mean','median','min','max']}).head(50)
# Out:
#                    salary_average                                        \
#                             count           mean     median         min
# location
# Amsterdam                       7   36462.857143      60.00      60.000
# Aurich                          1     675.000000     675.00     675.000
